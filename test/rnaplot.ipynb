# %%
import varnaapi
from varnaapi import Structure
import pandas as pd
import numpy as np
# Out:
# /tmp/ipykernel_1030666/1499831040.py:3: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
RNAs = pd.read_csv('/home/mescalin/yitao/Documents/Code/RNAfold/rna_dataset_88.csv')
rnas = RNAs.to_numpy()
rnas
# Out:
# array([['CACUUCUUCAUAAAUCCCUCACCGAUUACAGGACCAAAAUGGGGUAGUUGC',
#         '.(((.((((((.....(((..........)))......)))))).)))...',
#         -5.599999904632568],
#        ['GGUGCCAAUCUAGGGAAUCAAAAGAUGAAUUGGUUUUGUUCAUCAGC',
#         '(((.((.......)).)))....(((((((.......)))))))...',
#         -8.800000190734863],
#        ['AGGCUCGAGGAGGUUACCCCACGGGGUCAGUCAUAGUGUUUGAUAGCAUAUUUCUCGCGAUGCGCGCUCACAGAACGACGGGAUAUUCACCCGACGCACGCUCGGAAGGCCUACGGAU',
#         '(((((((((((....((((....))))...))...(((((....)))))..((((((((...)))).....))))((.((((.......)))).))....))))...)))))......',
#         -29.799999237060547],
#        ['CUAUCCUUACAUCGUGUAUGUCCGGGACCCACGCGCUUUUUGAAACAAGAGUUGAAGACGUACCGUU',
#         '............((.(((((((((.......)).((((((......))))))....)))))))))..',
#         -9.699999809265137],
#        ['C', '.', 0.0],
#        ['A', '.', 0.0],
# ...

# %%
i = 2
rna = rnas[i]
seq = rna[0]
ss = rna[1]
print(seq)
print(ss)
# Out:
# AGGCUCGAGGAGGUUACCCCACGGGGUCAGUCAUAGUGUUUGAUAGCAUAUUUCUCGCGAUGCGCGCUCACAGAACGACGGGAUAUUCACCCGACGCACGCUCGGAAGGCCUACGGAU
# (((((((((((....((((....))))...))...(((((....)))))..((((((((...)))).....))))((.((((.......)))).))....))))...)))))......

# %%
vis = Structure(sequence=seq,structure=ss)
vis.savefig(f"/home/mescalin/yitao/Documents/Code/RNAfold/RNA_88_{i}.svg")
vis
# Out:
# Output file: /home/mescalin/yitao/Documents/Code/RNAfold/RNA_88_2.svg
#
# Output file: /tmp/tmpi6jx3s1o.svg
# ('(((((((((((....((((....))))...))...(((((....)))))..((((((((...)))).....))))((.((((.......)))).))....))))...)))))......', 'AGGCUCGAGGAGGUUACCCCACGGGGUCAGUCAUAGUGUUUGAUAGCAUAUUUCUCGCGAUGCGCGCUCACAGAACGACGGGAUAUUCACCCGACGCACGCUCGGAAGGCCUACGGAU')
